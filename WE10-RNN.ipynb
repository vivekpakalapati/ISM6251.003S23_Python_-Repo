# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from sklearn.preprocessing import MinMaxScaler
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 4
#       2 import numpy as np
#       3 import matplotlib.pyplot as plt
# ----> 4 import tensorflow as tf
#       5 from sklearn.preprocessing import MinMaxScaler
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/tensorflow/__init__.py:41
#      38 import six as _six
#      39 import sys as _sys
# ---> 41 from tensorflow.python.tools import module_util as _module_util
#      42 from tensorflow.python.util.lazy_loader import LazyLoader as _LazyLoader
#      44 # Make sure code inside the TensorFlow codebase can use tf2.enabled() at import.
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/tensorflow/python/__init__.py:40
#      31 import traceback
#      33 # We aim to keep this file minimal and ideally remove completely.
#      34 # If you are adding a new file with @tf_export decorators,
#      35 # import it in modules_with_exports.py instead.
#      36
#      37 # go/tf-wildcard-import
#      38 # pylint: disable=wildcard-import,g-bad-import-order,g-import-not-at-top
# ---> 40 from tensorflow.python.eager import context
#      41 from tensorflow.python import pywrap_tensorflow as _pywrap_tensorflow
#      43 # pylint: enable=wildcard-import
#      44
#      45 # Bring in subpackages.
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/tensorflow/python/eager/context.py:32
#      29 import numpy as np
#      30 import six
# ---> 32 from tensorflow.core.framework import function_pb2
#      33 from tensorflow.core.protobuf import config_pb2
#      34 from tensorflow.core.protobuf import rewriter_config_pb2
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/tensorflow/core/framework/function_pb2.py:16
#      11 # @@protoc_insertion_point(imports)
#      13 _sym_db = _symbol_database.Default()
# ---> 16 from tensorflow.core.framework import attr_value_pb2 as tensorflow_dot_core_dot_framework_dot_attr__value__pb2
#      17 from tensorflow.core.framework import node_def_pb2 as tensorflow_dot_core_dot_framework_dot_node__def__pb2
#      18 from tensorflow.core.framework import op_def_pb2 as tensorflow_dot_core_dot_framework_dot_op__def__pb2
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/tensorflow/core/framework/attr_value_pb2.py:16
#      11 # @@protoc_insertion_point(imports)
#      13 _sym_db = _symbol_database.Default()
# ---> 16 from tensorflow.core.framework import tensor_pb2 as tensorflow_dot_core_dot_framework_dot_tensor__pb2
#      17 from tensorflow.core.framework import tensor_shape_pb2 as tensorflow_dot_core_dot_framework_dot_tensor__shape__pb2
#      18 from tensorflow.core.framework import types_pb2 as tensorflow_dot_core_dot_framework_dot_types__pb2
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/tensorflow/core/framework/tensor_pb2.py:16
#      11 # @@protoc_insertion_point(imports)
#      13 _sym_db = _symbol_database.Default()
# ---> 16 from tensorflow.core.framework import resource_handle_pb2 as tensorflow_dot_core_dot_framework_dot_resource__handle__pb2
#      17 from tensorflow.core.framework import tensor_shape_pb2 as tensorflow_dot_core_dot_framework_dot_tensor__shape__pb2
#      18 from tensorflow.core.framework import types_pb2 as tensorflow_dot_core_dot_framework_dot_types__pb2
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/tensorflow/core/framework/resource_handle_pb2.py:16
#      11 # @@protoc_insertion_point(imports)
#      13 _sym_db = _symbol_database.Default()
# ---> 16 from tensorflow.core.framework import tensor_shape_pb2 as tensorflow_dot_core_dot_framework_dot_tensor__shape__pb2
#      17 from tensorflow.core.framework import types_pb2 as tensorflow_dot_core_dot_framework_dot_types__pb2
#      20 DESCRIPTOR = _descriptor.FileDescriptor(
#      21   name='tensorflow/core/framework/resource_handle.proto',
#      22   package='tensorflow',
#    (...)
#      26   ,
#      27   dependencies=[tensorflow_dot_core_dot_framework_dot_tensor__shape__pb2.DESCRIPTOR,tensorflow_dot_core_dot_framework_dot_types__pb2.DESCRIPTOR,])
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/tensorflow/core/framework/tensor_shape_pb2.py:36
#      13 _sym_db = _symbol_database.Default()
#      18 DESCRIPTOR = _descriptor.FileDescriptor(
#      19   name='tensorflow/core/framework/tensor_shape.proto',
#      20   package='tensorflow',
#    (...)
#      23   serialized_pb=_b('\n,tensorflow/core/framework/tensor_shape.proto\x12\ntensorflow\"z\n\x10TensorShapeProto\x12-\n\x03\x64im\x18\x02 \x03(\x0b\x32 .tensorflow.TensorShapeProto.Dim\x12\x14\n\x0cunknown_rank\x18\x03 \x01(\x08\x1a!\n\x03\x44im\x12\x0c\n\x04size\x18\x01 \x01(\x03\x12\x0c\n\x04name\x18\x02 \x01(\tB\x87\x01\n\x18org.tensorflow.frameworkB\x11TensorShapeProtosP\x01ZSgithub.com/tensorflow/tensorflow/tensorflow/go/core/framework/tensor_shape_go_proto\xf8\x01\x01\x62\x06proto3')
#      24 )
#      29 _TENSORSHAPEPROTO_DIM = _descriptor.Descriptor(
#      30   name='Dim',
#      31   full_name='tensorflow.TensorShapeProto.Dim',
#      32   filename=None,
#      33   file=DESCRIPTOR,
#      34   containing_type=None,
#      35   fields=[
# ---> 36     _descriptor.FieldDescriptor(
#      37       name='size', full_name='tensorflow.TensorShapeProto.Dim.size', index=0,
#      38       number=1, type=3, cpp_type=2, label=1,
#      39       has_default_value=False, default_value=0,
#      40       message_type=None, enum_type=None, containing_type=None,
#      41       is_extension=False, extension_scope=None,
#      42       serialized_options=None, file=DESCRIPTOR),
#      43     _descriptor.FieldDescriptor(
#      44       name='name', full_name='tensorflow.TensorShapeProto.Dim.name', index=1,
#      45       number=2, type=9, cpp_type=9, label=1,
#      46       has_default_value=False, default_value=_b("").decode('utf-8'),
#      47       message_type=None, enum_type=None, containing_type=None,
#      48       is_extension=False, extension_scope=None,
#      49       serialized_options=None, file=DESCRIPTOR),
#      50   ],
#      51   extensions=[
#      52   ],
#      53   nested_types=[],
#      54   enum_types=[
#      55   ],
#      56   serialized_options=None,
#      57   is_extendable=False,
#      58   syntax='proto3',
#      59   extension_ranges=[],
#      60   oneofs=[
#      61   ],
#      62   serialized_start=149,
#      63   serialized_end=182,
#      64 )
#      66 _TENSORSHAPEPROTO = _descriptor.Descriptor(
#      67   name='TensorShapeProto',
#      68   full_name='tensorflow.TensorShapeProto',
#    (...)
#     100   serialized_end=182,
#     101 )
#     103 _TENSORSHAPEPROTO_DIM.containing_type = _TENSORSHAPEPROTO
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/google/protobuf/descriptor.py:561, in FieldDescriptor.__new__(cls, name, full_name, index, number, type, cpp_type, label, default_value, message_type, enum_type, containing_type, is_extension, extension_scope, options, serialized_options, has_default_value, containing_oneof, json_name, file, create_key)
#     555 def __new__(cls, name, full_name, index, number, type, cpp_type, label,
#     556             default_value, message_type, enum_type, containing_type,
#     557             is_extension, extension_scope, options=None,
#     558             serialized_options=None,
#     559             has_default_value=True, containing_oneof=None, json_name=None,
#     560             file=None, create_key=None):  # pylint: disable=redefined-builtin
# --> 561   _message.Message._CheckCalledFromGeneratedFile()
#     562   if is_extension:
#     563     return _message.default_pool.FindExtensionByName(full_name)
#
# TypeError: Descriptors cannot not be created directly.
# If this call came from a _pb2.py file, your generated code is out of date and must be regenerated with protoc >= 3.19.0.
# If you cannot immediately regenerate your protos, some other possible workarounds are:
#  1. Downgrade the protobuf package to 3.20.x or lower.
#  2. Set PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION=python (but this will use pure-Python parsing and will be much slower).
#
# More information: https://developers.google.com/protocol-buffers/docs/news/2022-05-06#python-updates

# %%
conda install tensorflow
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: failed with initial frozen solve. Retrying with flexible solve.
# Solving environment: failed with repodata from current_repodata.json, will retry with next repodata source.
# Collecting package metadata (repodata.json): done
# Solving environment: failed with initial frozen solve. Retrying with flexible solve.
# Solving environment: \
# Found conflicts! Looking for incompatible packages.
# This can take several minutes.  Press CTRL-C to abort.
#                                                                     \                                  failed
#
# UnsatisfiableError: The following specifications were found
# to be incompatible with the existing python installation in your environment:
#
# Specifications:
#
#   - appdirs -> python[version='>=2.7,<2.8.0a0|>=3.5,<3.6.0a0|>=3.6,<3.7.0a0|>=3.7,<3.8.0a0']
#   - argon2-cffi -> python[version='>=2.7,<2.8.0a0|>=3.11,<3.12.0a0|>=3.5,<3.6.0a0']
#   - argon2-cffi-bindings -> python[version='>=2.7,<2.8.0a0|>=3.6,<3.7.0a0|>=3.5,<3.6.0a0']
#   - backcall -> python[version='>=2.7,<2.8.0a0|>=3.5,<3.6.0a0|>=3.7,<3.8.0a0|>=3.8,<3.9.0a0|>=3.6,<3.7.0a0']
#   - backports -> python[version='>=2.7,<2.8.0a0|>=3.5,<3.6.0a0|>=3.7,<3.8.0a0|>=3.6,<3.7.0a0']
#   - backports.functools_lru_cache -> python[version='>=2.7,<2.8.0a0']
#   - brotlipy -> python[version='>=2.7,<2.8.0a0|>=3.5,<3.6.0a0']
#   - conda-content-trust -> python[version='>=2.7,<2.8.0a0|>=3.6,<3.7.0a0|>=3.5,<3.6.0a0']
#   - conda-package-streaming -> python[version='>=3.6,<3.7.0a0']
#   - conda-verify -> python[version='>=2.7,<2.8.0a0|>=3.6,<3.7.0a0|>=3.7,<3.8.0a0|>=3.5,<3.6.0a0']
#   - contourpy -> python[version='>=2.7,<2.8.0a0|>=3.6,<3.7.0a0']
#   - defusedxml -> python[version='>=2.7,<2.8.0a0|>=3.5,<3.6.0a0|>=3.6,<3.7.0a0|>=3.7,<3.8.0a0']
#   - glob2 -> python[version='>=2.7,<2.8.0a0|>=3.7,<3.8.0a0|>=3.6,<3.7.0a0|>=3.5,<3.6.0a0']
#   - ipython_genutils -> python[version='>=2.7,<2.8.0a0|>=3.6,<3.7.0a0|>=3.8,<3.9.0a0|>=3.7,<3.8.0a0|>=3.5,<3.6.0a0']
#   - pathlib -> python[version='>=2.7,<2.8.0a0|>=3.8,<3.9.0a0|>=3.6,<3.7.0a0|>=3.7,<3.8.0a0']
#   - pexpect -> python[version='>=2.7,<2.8.0a0|>=3.6,<3.7.0a0|>=3.7,<3.8.0a0|>=3.8,<3.9.0a0|>=3.5,<3.6.0a0']
#   - ptyprocess -> python[version='>=2.7,<2.8.0a0|>=3.7,<3.8.0a0|>=3.8,<3.9.0a0|>=3.6,<3.7.0a0|>=3.5,<3.6.0a0']
#   - pyrsistent -> python[version='>=3.5,<3.6.0a0']
#   - python-dateutil -> python[version='>=2.7,<2.8.0a0|>=3.6,<3.7.0a0|>=3.7,<3.8.0a0|>=3.5,<3.6.0a0']
#   - ruamel.yaml -> python[version='>=2.7,<2.8.0a0|>=3.5,<3.6.0a0']
#   - send2trash -> python[version='>=2.7,<2.8.0a0|>=3.5,<3.6.0a0|>=3.7,<3.8.0a0|>=3.8,<3.9.0a0|>=3.6,<3.7.0a0']
#   - sniffio -> python[version='>=3,<3.7']
#   - soupsieve -> python[version='>=3.5,<3.6.0a0']
#   - tinycss2 -> python[version='>=2.7,<2.8.0a0|>=3.5,<3.6.0a0|>=3.6,<3.7.0a0']
#   - wcwidth -> python[version='>=2.7,<2.8.0a0|>=3.6,<3.7.0a0|>=3.8,<3.9.0a0|>=3.7,<3.8.0a0|>=3.5,<3.6.0a0']
#   - websocket-client -> python[version='>=3.5,<3.6.0a0']
#   - zstandard -> python[version='>=3.5,<3.6.0a0']
#
# Your python: python=3.9
#
# If python is on the left-most side of the chain, that's the version you've asked for.
# When python appears to the right, that indicates that the thing on the left is somehow
# not available for the python version you are constrained to. Note that conda will not
# change your python version to a different minor version unless you explicitly specify
# that.
#
# The following specifications were found to be incompatible with a past
# explicit spec that is not an explicit spec in this operation (scipy):
#
#   - tensorflow -> tensorboard=2.10 -> numpy[version='>=1.12|>=1.12.0|>=1.20|>=1.16|>=1.16.5,<2.0a0|>=1.16.1|>=1.14.6,<2.0a0|>=1.13.3,<2.0a0']
#   - tensorflow -> tensorflow-base==2.10.0=eigen_py38h61e1807_0 -> scipy[version='>=1.7.3|>=1.7.3,<2']
#
# The following specifications were found to be incompatible with each other:
#
# Output in format: Requested package -> Available versions
#
# Package libcxx conflicts for:
# graphviz -> cairo[version='>=1.16.0,<2.0a0'] -> libcxx[version='>=10.0.0|>=14.0.4']
# sniffio -> python[version='>=3.9,<3.10.0a0'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# ghostscript -> libcxx[version='>=12.0.1']
# clangxx -> clang==10.0.0=default_hf57f61e_0 -> libcxx[version='4.0.1|4.0.1|>=10.0.0',build='h579ed51_0|hcfea43d_1']
# gst-plugins-base -> glib[version='>=2.69.1,<3.0a0'] -> libcxx[version='>=12.0.0|>=14.0.4']
# glib -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1|>=14.0.4']
# libclang13 -> libllvm14[version='>=14.0.6,<14.1.0a0'] -> libcxx[version='>=12|>=14']
# python.app -> python[version='>=3.7,<3.8.0a0'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# matplotlib-base -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# mkl -> tbb=2021 -> libcxx[version='>=10.0.0']
# r-base -> cairo[version='>=1.16.0,<2.0a0'] -> libcxx[version='>=10.0.0|>=12.0.1|>=14.0.4|>=12.0.0']
# r-checkmate -> r-base[version='>=4.1,<4.2.0a0'] -> libcxx[version='>=14.0.6|>=4.0.1']
# kiwisolver -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# clang -> libcxx[version='4.0.1|4.0.1|>=10.0.0',build='h579ed51_0|hcfea43d_1']
# libxslt -> icu[version='>=58.2,<59.0a0'] -> libcxx[version='>=4.0.1']
# pysocks -> python[version='>=3.8,<3.9.0a0'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# py-xgboost -> libcxx[version='>=10.0.0|>=4.0.1']
# backports.functools_lru_cache -> python -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# nbconvert -> python[version='>=3.7,<3.8.0a0'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# navigator-updater -> pyqt[version='>=5.6,<6.0a0'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# libllvm14 -> libcxx[version='>=12|>=14']
# clang -> clang-14==14.0.6=default_hd95374b_1 -> libcxx[version='>=12.0.0|>=14.0.6|>=4.0.1']
# r-digest -> r-base[version='>=3.6,<3.7.0a0'] -> libcxx[version='>=4.0.1']
# urllib3 -> python[version='>=3.9,<3.10.0a0'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# liblief -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# tinycss2 -> python[version='>=3.9,<3.10.0a0'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# r-rcpp -> libcxx[version='>=14.0.6|>=4.0.1']
# conda-repo-cli -> python[version='>=3.9,<3.10.0a0'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# r-curl -> r-base[version='>=4.1,<4.2.0a0'] -> libcxx[version='>=14.0.6|>=4.0.1']
# icu -> libcxx[version='>=10.0.0|>=4.0.1|>=12.0.1']
# qtwebkit -> glib -> libcxx[version='>=10.0.0|>=4.0.1|>=14.0.4|>=13.0.1|>=12.0.1']
# ipython -> python[version='>=3.8,<3.9.0a0'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# mkl-service -> python[version='>=3.8,<3.9.0a0'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# contourpy -> libcxx[version='>=12.0.0|>=14.0.6']
# sqlite -> ncurses[version='>=6.2,<7.0a0'] -> libcxx[version='>=4.0.1']
# libffi -> libcxx[version='>=10.0.0|>=12.0.0|>=4.0.1']
# pandocfilters -> python[version='!=3.0,!=3.1,!=3.2,!=3.3'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# libxgboost -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# toolz -> python[version='>=3.8,<3.9.0a0'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# r-cli -> libcxx[version='>=14.0.6']
# mkl_fft -> python[version='>=3.6,<3.7.0a0'] -> libcxx
# r-backports -> r-base[version='>=4.1,<4.2.0a0'] -> libcxx[version='>=14.0.6|>=4.0.1']
# comm -> python[version='>=3.7,<3.8.0a0'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# python-libarchive-c -> python -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# ruamel.yaml.clib -> python[version='>=3.7,<3.8.0a0'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# prometheus_client -> python[version='>=3.9,<3.10.0a0'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# r-purrr -> r-base[version='>=4.1,<4.2.0a0'] -> libcxx[version='>=14.0.4|>=14.0.6|>=4.0.1']
# r-htmltools -> r-rlang[version='>=0.4.10'] -> libcxx[version='>=14.0.4']
# pooch -> python[version='>=3.6'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# r-pillar -> r-base[version='>=4.1,<4.2.0a0'] -> libcxx[version='>=14.0.4|>=14.0.6|>=4.0.1']
# fontconfig -> expat[version='>=2.4.9,<3.0a0'] -> libcxx[version='>=12.0.0|>=14.0.4|>=4.0.1']
# gfortran_impl_osx-64 -> gmp[version='>=6.1.2'] -> libcxx[version='>=10.0.0|>=4.0.1|>=14.0.6']
# r-rapportools -> r-base[version='>=4.1,<4.2.0a0'] -> libcxx[version='>=14.0.4|>=14.0.6|>=4.0.1']
# gettext -> libffi[version='>=3.2.1,<3.3a0'] -> libcxx[version='>=4.0.1']
# wcwidth -> python -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# r-stringi -> libcxx[version='>=14.0.6|>=4.0.1']
# appdirs -> python -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# python=3.9 -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6']
# r-assertthat -> r-base[version='>=4.1,<4.2.0a0'] -> libcxx[version='>=14.0.6|>=4.0.1']
# entrypoints -> python[version='>=3.7,<3.8.0a0'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# numpy -> libcxx[version='>=12.0.0|>=14.0.6']
# libxml2 -> icu[version='>=58.2,<59.0a0'] -> libcxx[version='>=12.0.1|>=4.0.1']
# gfortran_impl_osx-64 -> libcxx[version='>=12.0.0']
# gsl -> libopenblas[version='>=0.3.20,<1.0a0'] -> libcxx[version='>=12.0.0']
# executing -> python[version='>=2.7'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# lerc -> libcxx[version='>=10.0.0|>=12.0.0']
# pexpect -> python -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# anyio -> python[version='>=3.8,<3.9.0a0'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# ld64 -> libllvm12[version='>=12.0.0,<12.1.0a0'] -> libcxx[version='>=*|>=10.0.0|>=10.0.0.a0|>=10.a0|>=12.0.0.a0|>=4.0.1']
# jsonschema -> python[version='>=3.8,<3.9.0a0'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# conda[version='>=23.3.1'] -> python[version='>=3.9,<3.10.0a0'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# libglib -> libcxx[version='>=14.0.4']
# boltons -> python[version='>=3.8,<3.9.0a0'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# nest-asyncio -> python[version='>=3.9,<3.10.0a0'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# r-crayon -> r-base[version='>=4.1,<4.2.0a0'] -> libcxx[version='>=14.0.6|>=4.0.1']
# r-lifecycle -> r-base[version='>=4.1,<4.2.0a0'] -> libcxx[version='>=14.0.4|>=14.0.6']
# cctools -> libllvm12[version='>=12.0.0,<12.1.0a0'] -> libcxx[version='>=10.0.0|>=10.a0|>=4.0.1']
# conda-token -> python -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# imagemagick -> ghostscript -> libcxx[version='>=12.0.1|>=14.0.4']
# lz4-c -> libcxx[version='>=10.0.0|>=14.0.6|>=12.0.0|>=4.0.1']
# r-tidyr -> libcxx[version='>=14.0.6|>=4.0.1']
# argon2-cffi -> python[version='>=3.6'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# nbformat -> python[version='>=3.7,<3.8.0a0'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# threadpoolctl -> python[version='>=3.6'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# pandas -> python[version='>=3.6,<3.7.0a0'] -> libcxx
# appnope -> python[version='>=3.6,<3.7.0a0'] -> libcxx[version='>=10.0.0|>=4.0.1|>=14.0.6|>=12.0.0']
# graphite2 -> libcxx[version='>=10.0.0|>=12.0.0|>=4.0.1']
# r-timechange -> libcxx[version='>=14.0.6|>=4.0.1']
# ujson -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# mkl_random -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# libllvm14 -> libffi[version='>=3.4,<3.5'] -> libcxx[version='>=10.0.0|>=12.0.0|>=4.0.1']
# matplotlib -> libcxx[version='>=4.0.1']
# r-vctrs -> r-rlang[version='>=1.0.6'] -> libcxx[version='>=14.0.4']
# gtk2 -> cairo[version='>=1.16.0,<2.0a0'] -> libcxx[version='>=10.0.0|>=4.0.1|>=14.0.6|>=12.0.0|>=14.0.4']
# chardet -> python[version='>=3.6,<3.7.0a0'] -> libcxx[version='>=10.0.0|>=4.0.1|>=14.0.6|>=12.0.0']
# attrs -> python[version='>=3.7,<3.8.0a0'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# compiler-rt -> clang=10.0.0 -> libcxx[version='>=10.0.0|>=9.0.1']
# r-lobstr -> r-rlang[version='>=1.0.0'] -> libcxx[version='>=14.0.4']
# r-reshape2 -> libcxx[version='>=14.0.4|>=4.0.1']
# r-stringr -> r-base[version='>=4.1,<4.2.0a0'] -> libcxx[version='>=14.0.4|>=14.0.6|>=4.0.1']
# r-pander -> r-base[version='>=4.1,<4.2.0a0'] -> libcxx[version='>=14.0.6']
# ipykernel -> debugpy[version='>=1.0'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# future -> python[version='>=3.7,<3.8.0a0'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# filelock -> python[version='>=3.8,<3.9.0a0'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# r-base -> libcxx[version='>=14.0.6|>=4.0.1']
# libarchive -> lz4-c[version='>=1.9.4,<1.10.0a0'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1|>=14.0.4']
# pyqt -> qt-main=5.15 -> libcxx[version='>=13.0.1']
# packaging -> python[version='>=3.8,<3.9.0a0'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# brotlipy -> python[version='>=3.6,<3.7.0a0'] -> libcxx[version='>=10.0.0|>=4.0.1|>=14.0.6|>=12.0.0']
# intel-openmp -> libcxx[version='>=12.0.0|>=14.0.6']
# mpc -> gmp[version='>=6.1.2'] -> libcxx[version='>=10.0.0|>=12.0.0|>=4.0.1']
# ncurses -> libcxx[version='>=4.0.1']
# joblib -> python[version='>=3.7,<3.8.0a0'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# soupsieve -> python[version='>=3.8,<3.9.0a0'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# traitlets -> python[version='>=3.7,<3.8.0a0'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# asttokens -> python[version='>=3.5'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# cctools -> libcxx==4.0.1[build='h579ed51_0|hcfea43d_1']
# idna -> python[version='>=3.9,<3.10.0a0'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# isl -> libcxx[version='>=12.0.0']
# r-pkgconfig -> r-base[version='>=4.1,<4.2.0a0'] -> libcxx[version='>=14.0.6|>=4.0.1']
# compiler-rt_osx-64 -> libcxx[version='>=9.0.1']
# pyrsistent -> python[version='>=3.7,<3.8.0a0'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# anaconda-clean -> python[version='>=3.7,<3.8.0a0'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# backports.tempfile -> python -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# pip -> python[version='>=3.8,<3.9.0a0'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# jedi -> python[version='>=3.9,<3.10.0a0'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# mkl -> libcxx[version='>=12.0.0|>=14.0.6']
# r-base64enc -> r-base[version='>=4.1,<4.2.0a0'] -> libcxx[version='>=14.0.6|>=4.0.1']
# imagemagick -> libcxx[version='>=14.0.6']
# click -> python[version='>=3.9,<3.10.0a0'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# r-magrittr -> r-base[version='>=4.1,<4.2.0a0'] -> libcxx[version='>=14.0.6|>=4.0.1']
# python=3.9 -> libffi[version='>=3.3,<3.4.0a0'] -> libcxx[version='>=4.0.1']
# gstreamer -> gettext -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.4|>=4.0.1']
# cairo -> libcxx[version='>=10.0.0|>=4.0.1']
# r-tibble -> r-base[version='>=4.1,<4.2.0a0'] -> libcxx[version='>=14.0.4|>=14.0.6']
# r-tidyselect -> r-base[version='>=4.1,<4.2.0a0'] -> libcxx[version='>=14.0.4|>=14.0.6']
# markupsafe -> python[version='>=3.7,<3.8.0a0'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# pytz -> python[version='>=3.7,<3.8.0a0'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# ld64 -> libcxx==4.0.1[build='h579ed51_0|hcfea43d_1']
# pygments -> python[version='>=3.5'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# fftw -> libcxx[version='>=14.0.6']
# sip -> python[version='>=3.6,<3.7.0a0'] -> libcxx
# matplotlib -> matplotlib-base[version='>=3.7.1,<3.7.2.0a0'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6']
# numpy-base -> libcxx[version='>=12.0.0|>=14.0.6']
# argon2-cffi-bindings -> python[version='>=3.9,<3.10.0a0'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# jupyter_client -> python[version='>=3.8,<3.9.0a0'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# conda-package-handling -> python[version='>=3.7,<3.8.0a0'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# flit-core -> python[version='>=3.8,<3.9.0a0'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# r-vctrs -> libcxx[version='>=14.0.6']
# r-htmltools -> libcxx[version='>=14.0.6|>=4.0.1']
# openpyxl -> python[version='>=3.9,<3.10.0a0'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# r-tidyselect -> libcxx[version='>=4.0.1']
# matplotlib-base -> python[version='>=3.6,<3.7.0a0'] -> libcxx
# libwebp -> libtiff[version='>=4.1.0,<5.0a0'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# charset-normalizer -> python[version='>=3.5'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# typing_extensions -> python[version='>=3.8,<3.9.0a0'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# glib-tools -> libcxx[version='>=14.0.4']
# curl -> krb5[version='>=1.17.1,<1.18.0a0'] -> libcxx[version='>=4.0.1']
# prompt-toolkit -> python[version='>=3.8,<3.9.0a0'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# libgd -> libcxx[version='>=14.0.6']
# zstandard -> libcxx[version='>=10.0.0|>=4.0.1']
# gettext -> libcxx[version='>=10.0.0|>=14.0.6']
# requests -> python[version='>=3.9,<3.10.0a0'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# webencodings -> python[version='>=3.9,<3.10.0a0'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# gts -> libcxx[version='>=10.0.0|>=12.0.0']
# tornado -> python[version='>=3.8,<3.9.0a0'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# gstreamer -> libcxx[version='>=14.0.6']
# pure_eval -> python[version='>=3.5'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# r-codetools -> r-base[version='>=4.1,<4.2.0a0'] -> libcxx[version='>=14.0.6|>=4.0.1']
# libgd -> expat[version='>=2.4.9,<3.0a0'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.4|>=4.0.1|>=12.0.1']
# pyopenssl -> python[version='>=3.8,<3.9.0a0'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# r-lobstr -> libcxx[version='>=14.0.6']
# bleach -> python[version='>=3.6'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# bottleneck -> numpy[version='>=1.22.3,<2.0a0'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# numexpr -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# clang_osx-64 -> cctools_osx-64 -> libcxx[version='4.0.1|>=10.0.0|>=9.0.1',build='h579ed51_0|hcfea43d_1']
# zeromq -> libcxx[version='>=10.0.0|>=4.0.1']
# python_abi -> python=3.9 -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6']
# qtwebkit -> libcxx[version='>=12.0.0|>=14.0.6']
# pandas -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# et_xmlfile -> python[version='>=3.9,<3.10.0a0'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# pyqt5-sip -> sip -> libcxx[version='>=10.0.0|>=4.0.1']
# debugpy -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6']
# py-lief -> python[version='>=3.6,<3.7.0a0'] -> libcxx
# scipy -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# backports -> python -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# python-fastjsonschema -> python[version='>=3.8,<3.9.0a0'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# r-ellipsis -> r-base[version='>=4.1,<4.2.0a0'] -> libcxx[version='>=14.0.4|>=14.0.6|>=4.0.1']
# r-summarytools -> r-base[version='>=4.1,<4.2.0a0'] -> libcxx[version='>=14.0.4|>=14.0.6|>=4.0.1']
# ninja-base -> libcxx[version='>=12.0.0']
# scikit-learn -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# lxml -> python[version='>=3.9,<3.10.0a0'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# jupyter_server -> pyzmq[version='>=17'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# pillow -> libcxx[version='>=12.0.0|>=14.0.6']
# tensorflow -> python=3.8 -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# cairo -> glib[version='>=2.69.1,<3.0a0'] -> libcxx[version='>=12.0.0|>=14.0.6|>=14.0.4']
# conda-build -> cctools -> libcxx[version='4.0.1|>=14.0.6|>=12.0.0|>=10.0.0|>=4.0.1',build='h579ed51_0|hcfea43d_1']
# wheel -> python[version='>=3.7,<3.8.0a0'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# llvm-tools -> libllvm14==14.0.6=h91fad77_2 -> libcxx[version='>=10.a0|>=12|>=14|>=4.0.1']
# debugpy -> python[version='>=3.8,<3.9.0a0'] -> libcxx[version='>=4.0.1']
# certifi -> python[version='>=3.8,<3.9.0a0'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# clang-14 -> libllvm14[version='>=14.0.6,<14.1.0a0'] -> libcxx[version='>=12|>=14']
# conda-content-trust -> python[version='>=3.8,<3.9.0a0'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# r-reshape2 -> r-base[version='>=4.1,<4.2.0a0'] -> libcxx[version='>=14.0.6']
# r-dplyr -> r-rlang[version='>=0.4.10'] -> libcxx[version='>=14.0.4']
# defusedxml -> python -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# mysql-libs -> libcxx[version='>=14.0.6']
# libnghttp2 -> libcxx[version='>=10.0.0|>=12.0.0']
# r-cli -> r-base[version='>=3.6,<3.7.0a0'] -> libcxx[version='>=4.0.1']
# readline -> ncurses[version='>=6.2,<7.0a0'] -> libcxx[version='>=4.0.1']
# pkginfo -> python[version='>=3.8,<3.9.0a0'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# tapi -> libcxx[version='>=*|>=10.0.0.a0|>=12.0.0.a0']
# six -> python -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# r-r6 -> r-base[version='>=4.1,<4.2.0a0'] -> libcxx[version='>=14.0.6|>=4.0.1']
# jinja2 -> python[version='>=3.9,<3.10.0a0'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# pyjwt -> python[version='>=3.7,<3.8.0a0'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# pyzmq -> zeromq[version='>=4.3.4,<4.4.0a0'] -> libcxx[version='>=10.0.0']
# r-tibble -> libcxx[version='>=4.0.1']
# zstd -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# clangxx_osx-64 -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# libclang13 -> libcxx[version='>=12.0.0|>=14.0.6']
# ruamel.yaml -> python[version='>=3.8,<3.9.0a0'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# numexpr -> python[version='>=3.6,<3.7.0a0'] -> libcxx
# librsvg -> cairo[version='>=1.16.0,<2.0a0'] -> libcxx[version='>=10.0.0|>=14.0.6|>=12.0.0|>=14.0.4']
# qtpy -> python[version='>=3.8,<3.9.0a0'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# r-mass -> r-base[version='>=4.1,<4.2.0a0'] -> libcxx[version='>=14.0.6|>=4.0.1']
# send2trash -> python -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# libclang -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6']
# conda-package-streaming -> python[version='>=3.8,<3.9.0a0'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# setuptools -> python[version='>=3.9,<3.10.0a0'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# psutil -> python[version='>=3.7,<3.8.0a0'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# r-rlang -> libcxx[version='>=14.0.4']
# tqdm -> python[version='>=3.8,<3.9.0a0'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# clyent -> python[version='>=3.9,<3.10.0a0'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# python-dateutil -> python -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# ply -> python[version='>=3.9,<3.10.0a0'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# backports.weakref -> python -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# sip -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# notebook-shim -> python[version='>=3.8,<3.9.0a0'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# stack_data -> python[version='>=3.5'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# toml -> python[version='>=2.7'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# libclang-cpp14 -> libllvm14[version='>=14.0.6,<14.1.0a0'] -> libcxx[version='>=12|>=14']
# scikit-learn -> python[version='>=3.6,<3.7.0a0'] -> libcxx
# lcms2 -> libtiff[version='>=4.1.0,<5.0a0'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# r-rlang -> r-base[version='>=4.1,<4.2.0a0'] -> libcxx[version='>=14.0.6|>=4.0.1']
# mysql-common -> libcxx[version='>=14.0.6']
# jupyter_core -> python[version='>=3.8,<3.9.0a0'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# notebook -> python[version='>=3.8,<3.9.0a0'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# openjpeg -> libcxx[version='>=10.0.0|>=4.0.1|>=14.0.6']
# numpy-base -> python[version='>=3.9,<3.10.0a0'] -> libcxx[version='>=10.0.0|>=4.0.1']
# libedit -> ncurses[version='>=6.2,<7.0a0'] -> libcxx[version='>=4.0.1']
# beautifulsoup4 -> python[version='>=3.8,<3.9.0a0'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# nss -> libcxx[version='>=12.0.0|>=4.0.1|>=14.0.6']
# numpy -> mkl_fft -> libcxx[version='>=10.0.0|>=4.0.1']
# r-fastmap -> libcxx[version='>=14.0.6|>=4.0.1']
# pluggy -> python[version='>=3.8,<3.9.0a0'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# cffi -> libffi[version='>=3.4,<3.5'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# gst-plugins-base -> libcxx[version='>=10.0.0|>=14.0.6|>=4.0.1']
# anaconda-client -> python[version='>=3.9,<3.10.0a0'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# pycparser -> python[version='>=3.6'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# qt-main -> glib[version='>=2.69.1,<3.0a0'] -> libcxx[version='>=10.0.0|>=14.0.4|>=4.0.1|>=12.0.1']
# r-generics -> r-base[version='>=4.1,<4.2.0a0'] -> libcxx[version='>=14.0.6|>=4.0.1']
# clangxx_osx-64 -> libllvm14[version='>=14.0.6,<14.1.0a0'] -> libcxx[version='>=10.a0|>=12|>=14']
# terminado -> python[version='>=3.7,<3.8.0a0'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# platformdirs -> python[version='>=3.7,<3.8.0a0'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# r-lubridate -> libcxx[version='>=4.0.1']
# r-magick -> imagemagick[version='>=7.1.0.49,<7.1.1.0a0'] -> libcxx[version='>=14.0.6|>=4.0.1']
# pcre -> libcxx[version='>=10.0.0|>=4.0.1']
# contourpy -> python[version='>=3.7,<3.8.0a0'] -> libcxx[version='>=10.0.0|>=4.0.1']
# ninja -> libcxx[version='>=10.0.0|>=12.0.0|>=4.0.1']
# pyyaml -> python[version='>=3.9,<3.10.0a0'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# matplotlib-inline -> python[version='>=3.8,<3.9.0a0'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# parso -> python[version='>=3.6'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# r-utf8 -> r-base[version='>=4.1,<4.2.0a0'] -> libcxx[version='>=14.0.6|>=4.0.1']
# libllvm15 -> libcxx[version='>=14']
# r-glue -> r-base[version='>=4.1,<4.2.0a0'] -> libcxx[version='>=14.0.6|>=4.0.1']
# r-tidyr -> r-rlang[version='>=1.0.4'] -> libcxx[version='>=14.0.4']
# ptyprocess -> python -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# jsonpointer -> python -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# brotli -> libcxx[version='>=10.0.0|>=4.0.1']
# harfbuzz -> glib[version='>=2.69.1,<3.0a0'] -> libcxx[version='>=12.0.1|>=14.0.4']
# r-digest -> libcxx[version='>=14.0.6']
# conda-verify -> python -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# pathlib -> python[version='>=3.8,<3.9.0a0'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# r-stringi -> icu[version='>=70.1,<71.0a0'] -> libcxx[version='>=12.0.1']
# cryptography -> python[version='>=3.9,<3.10.0a0'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# pyqt5-sip -> libcxx[version='>=12.0.0|>=14.0.6']
# r-prettyunits -> r-base[version='>=4.1,<4.2.0a0'] -> libcxx[version='>=14.0.6|>=4.0.1']
# r-cpp11 -> r-base[version='>=4.1,<4.2.0a0'] -> libcxx[version='>=14.0.6']
# qt-main -> libcxx[version='>=12.0.0|>=14.0.6|>=13.0.1']
# libcurl -> libnghttp2[version='>=1.46.0'] -> libcxx[version='>=10.0.0|>=12.0.0|>=4.0.1']
# r-magick -> libcxx[version='>=14.0.4']
# compiler-rt_osx-64 -> clang=10.0.0 -> libcxx[version='>=10.0.0']
# cctools_osx-64 -> libcxx
# jsonpatch -> python -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# mistune -> python[version='>=3.8,<3.9.0a0'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# clang-14 -> libcxx[version='>=12.0.0|>=14.0.6']
# munkres -> python -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# nbclassic -> python[version='>=3.9,<3.10.0a0'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# backcall -> python -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# scipy -> python[version='>=3.6,<3.7.0a0'] -> libcxx
# krb5 -> libcxx[version='>=4.0.1']
# gobject-introspection -> gettext -> libcxx[version='>=10.0.0|>=14.0.6|>=12.0.0|>=14.0.4|>=4.0.1']
# nbclient -> python[version='>=3.9,<3.10.0a0'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# llvm-tools -> libcxx[version='>=10.0.0|>=4.0.0']
# glob2 -> python -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# r-pander -> libcxx[version='>=14.0.4|>=4.0.1']
# gdk-pixbuf -> gettext[version='>=0.21.0,<1.0a0'] -> libcxx[version='>=10.0.0|>=14.0.6|>=12.0.0|>=4.0.1|>=14.0.4']
# anaconda-navigator -> pillow[version='>=8.2'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# libllvm12 -> libcxx[version='>=10.a0']
# typing-extensions -> python[version='>=3.8,<3.9.0a0'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# atk-1.0 -> gettext[version='>=0.21.0,<1.0a0'] -> libcxx[version='>=10.0.0|>=14.0.6|>=12.0.0|>=14.0.4|>=4.0.1']
# zstandard -> python[version='>=3.9,<3.10.0a0'] -> libcxx[version='>=12.0.0|>=14.0.6']
# pyparsing -> python[version='>=3.8,<3.9.0a0'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# harfbuzz -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# ujson -> python[version='>=3.6,<3.7.0a0'] -> libcxx
# r-dplyr -> libcxx[version='>=14.0.6|>=4.0.1']
# py-lief -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# xgboost -> python[version='>=3.9,<3.10.0a0'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# decorator -> python[version='>=3.5'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# qt-webengine -> qt-main[version='>=5.15,<6.0a0'] -> libcxx[version='>=13.0.1|>=14.0.6']
# r-lubridate -> r-base[version='>=4.1,<4.2.0a0'] -> libcxx[version='>=14.0.6']
# r-fansi -> r-base[version='>=4.1,<4.2.0a0'] -> libcxx[version='>=14.0.6|>=4.0.1']
# graphviz -> libcxx[version='>=12.0.0|>=14.0.6|>=4.0.1']
# gmp -> libcxx[version='>=10.0.0|>=12.0.0|>=4.0.1']
# gts -> glib[version='>=2.69.1,<3.0a0'] -> libcxx[version='>=14.0.4|>=14.0.6']
# seaborn -> matplotlib-base[version='>=3.1,!=3.6.1'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# pango -> cairo[version='>=1.12.10'] -> libcxx[version='>=10.0.0|>=4.0.1|>=14.0.6|>=12.0.0|>=14.0.4']
# nspr -> libcxx[version='>=12.0.0|>=4.0.1|>=14.0.6']
# mkl_fft -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# tapi -> ncurses[version='>=6.2,<7.0a0'] -> libcxx[version='>=4.0.1']
# gfortran_osx-64 -> cctools_osx-64 -> libcxx[version='4.0.1|4.0.1|>=10.0.0|>=12.0.0',build='h579ed51_0|hcfea43d_1']
# pickleshare -> python[version='>=3'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# libclang -> libllvm14[version='>=14.0.6,<14.1.0a0'] -> libcxx[version='>=10.a0|>=12|>=14|>=4.0.1']
# r-plyr -> libcxx[version='>=14.0.6|>=4.0.1']
# pycosat -> python[version='>=3.8,<3.9.0a0'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# r-matrixstats -> r-base[version='>=4.1,<4.2.0a0'] -> libcxx[version='>=14.0.6|>=4.0.1']
# r-pryr -> libcxx[version='>=14.0.6|>=4.0.1']
# libtiff -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# mysql-libs -> zstd[version='>=1.5.2,<1.6.0a0'] -> libcxx[version='>=12.0.0']
# mkl_random -> python[version='>=3.6,<3.7.0a0'] -> libcxx
# glib -> python= -> libcxx
# libllvm15 -> zstd[version='>=1.5.2,<1.6.0a0'] -> libcxx[version='>=12.0.0|>=14.0.6']
# openjpeg -> libtiff[version='>=4.1.0,<5.0a0'] -> libcxx[version='>=12.0.0']
# ipython_genutils -> python -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# pillow -> libtiff[version='>=4.2.0,<5.0a0'] -> libcxx[version='>=10.0.0|>=4.0.1']
# pyzmq -> libcxx[version='>=12.0.0|>=14.0.6|>=4.0.1']
# cctools_osx-64 -> libllvm14[version='>=14.0.6,<14.1.0a0'] -> libcxx[version='>=10.a0|>=12|>=14']
# kiwisolver -> python[version='>=3.6,<3.7.0a0'] -> libcxx
# qt-webengine -> libcxx[version='>=12.0.0']
# websocket-client -> python[version='>=3.6,<3.7.0a0'] -> libcxx[version='>=10.0.0|>=4.0.1|>=14.0.6|>=12.0.0']
# ld64_osx-64 -> libllvm14[version='>=14.0.6,<14.1.0a0'] -> libcxx[version='>=*|>=12|>=14|>=10.a0']
# fonttools -> brotli[version='>=1.0.1'] -> libcxx[version='>=10.0.0|>=4.0.1|>=14.0.6|>=12.0.0']
# cycler -> python[version='>=3.6'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# pyqt -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# jupyterlab_pygments -> python -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# ninja -> python -> libcxx[version='>=14.0.6']
# libpq -> krb5[version='>=1.17.1,<1.18.0a0'] -> libcxx[version='>=4.0.1']
# libglib -> libffi[version='>=3.4,<4.0a0'] -> libcxx[version='>=10.0.0|>=12.0.0']
# ld64_osx-64 -> libcxx
# py-xgboost -> libxgboost==1.7.3=hcec6c5f_0 -> libcxx[version='>=12.0.0|>=14.0.6']
# r-withr -> r-base[version='>=4.1,<4.2.0a0'] -> libcxx[version='>=14.0.6|>=4.0.1']
# libclang-cpp14 -> libcxx[version='>=12.0.0|>=14.0.6']
# mpfr -> gmp[version='>=6.1.2'] -> libcxx[version='>=10.0.0|>=12.0.0|>=4.0.1']
# expat -> libcxx[version='>=10.0.0|>=12.0.0|>=4.0.1|>=14.0.4']
#
# Package pip conflicts for:
# nest-asyncio -> python[version='>=3.11,<3.12.0a0'] -> pip
# et_xmlfile -> python[version='>=3.11,<3.12.0a0'] -> pip
# ruamel.yaml.clib -> python[version='>=3.11,<3.12.0a0'] -> pip
# ipykernel -> python[version='>=3.11,<3.12.0a0'] -> pip
# conda-build -> python[version='>=3.10,<3.11.0a0'] -> pip
# pillow -> python[version='>=3.11,<3.12.0a0'] -> pip
# qtpy -> python[version='>=3.11,<3.12.0a0'] -> pip
# ipython -> python[version='>=3.8,<3.9.0a0'] -> pip
# anaconda-navigator -> python[version='>=3.9,<3.10.0a0'] -> pip
# pyqt5-sip -> python[version='>=3.11,<3.12.0a0'] -> pip
# ptyprocess -> python -> pip
# clyent -> python[version='>=3.11,<3.12.0a0'] -> pip
# jsonschema -> python[version='>=3.11,<3.12.0a0'] -> pip
# fonttools -> python[version='>=3.6'] -> pip
# pyparsing -> python[version='>=3.11,<3.12.0a0'] -> pip
# py-xgboost -> python[version='>=3.11,<3.12.0a0'] -> pip
# ply -> python[version='>=3.11,<3.12.0a0'] -> pip
# tqdm -> python[version='>=3.10,<3.11.0a0'] -> pip
# conda-repo-cli -> python[version='>=3.10,<3.11.0a0'] -> pip
# filelock -> python[version='>=3.11,<3.12.0a0'] -> pip
# jupyterlab_pygments -> python -> pip
# matplotlib-inline -> python[version='>=3.11,<3.12.0a0'] -> pip
# xgboost -> python[version='>=3.11,<3.12.0a0'] -> pip
# requests -> python[version='>=3.11,<3.12.0a0'] -> pip
# pyjwt -> python[version='>=3.11,<3.12.0a0'] -> pip
# mkl_fft -> python[version='>=3.11,<3.12.0a0'] -> pip
# pexpect -> python -> pip
# mistune -> python[version='>=3.11,<3.12.0a0'] -> pip
# jedi -> python[version='>=3.11,<3.12.0a0'] -> pip
# pygments -> python[version='>=3.5'] -> pip
# numpy -> python[version='>=3.11,<3.12.0a0'] -> pip
# numexpr -> python[version='>=3.11,<3.12.0a0'] -> pip
# ninja -> python -> pip
# boltons -> python[version='>=3.11,<3.12.0a0'] -> pip
# psutil -> python[version='>=3.11,<3.12.0a0'] -> pip
# attrs -> python[version='>=3.11,<3.12.0a0'] -> pip
# pyopenssl -> python[version='>=3.11,<3.12.0a0'] -> pip
# conda[version='>=23.3.1'] -> python[version='>=3.9,<3.10.0a0'] -> pip
# typing-extensions -> python[version='>=3.8,<3.9.0a0'] -> pip
# notebook-shim -> python[version='>=3.11,<3.12.0a0'] -> pip
# click -> python[version='>=3.11,<3.12.0a0'] -> pip
# python=3.9 -> pip
# python-fastjsonschema -> python[version='>=3.11,<3.12.0a0'] -> pip
# bottleneck -> python[version='>=3.11,<3.12.0a0'] -> pip
# pluggy -> python[version='>=3.11,<3.12.0a0'] -> pip
# wheel -> python[version='>=3.11,<3.12.0a0'] -> pip
# idna -> python[version='>=3.11,<3.12.0a0'] -> pip
# py-lief -> python[version='>=3.11,<3.12.0a0'] -> pip
# tornado -> python[version='>=3.11,<3.12.0a0'] -> pip
# terminado -> python[version='>=3.11,<3.12.0a0'] -> pip
# contourpy -> python[version='>=3.11,<3.12.0a0'] -> pip
# debugpy -> python[version='>=3.11,<3.12.0a0'] -> pip
# conda-package-streaming -> python[version='>=3.11,<3.12.0a0'] -> pip
# appdirs -> python -> pip
# argon2-cffi -> python[version='>=3.6'] -> pip
# certifi -> python[version='>=3.11,<3.12.0a0'] -> pip
# gobject-introspection -> python[version='>=3.11,<3.12.0a0'] -> pip
# pooch -> python[version='>=3.6'] -> pip
# ruamel.yaml -> python[version='>=3.11,<3.12.0a0'] -> pip
# packaging -> python[version='>=3.8,<3.9.0a0'] -> pip
# bleach -> python[version='>=3.6'] -> pip
# charset-normalizer -> python[version='>=3.5'] -> pip
# pandocfilters -> python[version='!=3.0,!=3.1,!=3.2,!=3.3'] -> pip
# decorator -> python[version='>=3.5'] -> pip
# scikit-learn -> python[version='>=3.10,<3.11.0a0'] -> pip
# notebook -> python[version='>=3.8,<3.9.0a0'] -> pip
# backports.tempfile -> python -> pip
# pyyaml -> python[version='>=3.11,<3.12.0a0'] -> pip
# beautifulsoup4 -> python[version='>=3.8,<3.9.0a0'] -> pip
# jupyter_server -> python[version='>=3.11,<3.12.0a0'] -> pip
# argon2-cffi-bindings -> python[version='>=3.11,<3.12.0a0'] -> pip
# pkginfo -> python[version='>=3.8,<3.9.0a0'] -> pip
# jinja2 -> python[version='>=3.11,<3.12.0a0'] -> pip
# pyzmq -> python[version='>=3.11,<3.12.0a0'] -> pip
# flit-core -> python[version='>=3.10,<3.11.0a0'] -> pip
# python-dateutil -> python -> pip
# nbclient -> python[version='>=3.11,<3.12.0a0'] -> pip
# jupyter_client -> python[version='>=3.8,<3.9.0a0'] -> pip
# toolz -> python[version='>=3.11,<3.12.0a0'] -> pip
# tinycss2 -> python[version='>=3.11,<3.12.0a0'] -> pip
# send2trash -> python -> pip
# prompt-toolkit -> python[version='>=3.11,<3.12.0a0'] -> pip
# conda-token -> python -> pip
# prometheus_client -> python[version='>=3.11,<3.12.0a0'] -> pip
# zstandard -> python[version='>=3.11,<3.12.0a0'] -> pip
# pycosat -> python[version='>=3.11,<3.12.0a0'] -> pip
# backports.weakref -> python -> pip
# executing -> python[version='>=2.7'] -> pip
# matplotlib -> python[version='>=3.9,<3.10.0a0'] -> pip
# conda-content-trust -> python[version='>=3.11,<3.12.0a0'] -> pip
# entrypoints -> python[version='>=3.11,<3.12.0a0'] -> pip
# pathlib -> python[version='>=3.8,<3.9.0a0'] -> pip
# cryptography -> python[version='>=3.11,<3.12.0a0'] -> pip
# anaconda-client -> python[version='>=3.9,<3.10.0a0'] -> pip
# openpyxl -> python[version='>=3.11,<3.12.0a0'] -> pip
# joblib -> python[version='>=3.11,<3.12.0a0'] -> pip
# urllib3 -> python[version='>=3.10,<3.11.0a0'] -> pip
# conda-verify -> python -> pip
# backports -> python -> pip
# traitlets -> python[version='>=3.11,<3.12.0a0'] -> pip
# comm -> python[version='>=3.11,<3.12.0a0'] -> pip
# parso -> python[version='>=3.6'] -> pip
# glib -> python= -> pip
# ipython_genutils -> python -> pip
# pyrsistent -> python[version='>=3.11,<3.12.0a0'] -> pip
# webencodings -> python[version='>=3.11,<3.12.0a0'] -> pip
# cffi -> python[version='>=3.11,<3.12.0a0'] -> pip
# nbformat -> python[version='>=3.11,<3.12.0a0'] -> pip
# markupsafe -> python[version='>=3.11,<3.12.0a0'] -> pip
# soupsieve -> python[version='>=3.8,<3.9.0a0'] -> pip
# glob2 -> python -> pip
# asttokens -> python[version='>=3.5'] -> pip
# matplotlib-base -> python[version='>=3.9,<3.10.0a0'] -> pip
# platformdirs -> python[version='>=3.11,<3.12.0a0'] -> pip
# jsonpatch -> python -> pip
# appnope -> python[version='>=3.11,<3.12.0a0'] -> pip
# munkres -> python -> pip
# backports.functools_lru_cache -> python -> pip
# nbclassic -> python[version='>=3.9,<3.10.0a0'] -> pip
# navigator-updater -> python[version='>=3.10,<3.11.0a0'] -> pip
# jupyter_core -> python[version='>=3.8,<3.9.0a0'] -> pip
# backcall -> python -> pip
# numpy-base -> python[version='>=3.11,<3.12.0a0'] -> pip
# nbconvert -> python[version='>=3.11,<3.12.0a0'] -> pip
# pure_eval -> python[version='>=3.5'] -> pip
# setuptools -> python[version='>=3.10,<3.11.0a0'] -> pip
# pycparser -> python[version='>=3.6'] -> pip
# wcwidth -> python -> pip
# ujson -> python[version='>=3.11,<3.12.0a0'] -> pip
# stack_data -> python[version='>=3.5'] -> pip
# future -> python[version='>=3.11,<3.12.0a0'] -> pip
# tensorflow -> python=3.8 -> pip
# pickleshare -> python[version='>=3'] -> pip
# python-libarchive-c -> python -> pip
# mkl_random -> python[version='>=3.11,<3.12.0a0'] -> pip
# seaborn -> python[version='>=3.11,<3.12.0a0'] -> pip
# websocket-client -> python[version='>=3.11,<3.12.0a0'] -> pip
# jsonpointer -> python -> pip
# brotlipy -> python[version='>=3.6,<3.7.0a0'] -> pip
# threadpoolctl -> python[version='>=3.6'] -> pip
# sniffio -> python[version='>=3.11,<3.12.0a0'] -> pip
# scipy -> python[version='>=3.11,<3.12.0a0'] -> pip
# python.app -> python[version='>=3.11,<3.12.0a0'] -> pip
# python_abi -> python=3.9 -> pip
# six -> python -> pip
# kiwisolver -> python[version='>=3.11,<3.12.0a0'] -> pip
# anaconda-clean -> python[version='>=3.11,<3.12.0a0'] -> pip
# conda-package-handling -> python[version='>=3.11,<3.12.0a0'] -> pip
# pytz -> python[version='>=3.11,<3.12.0a0'] -> pip
# lxml -> python[version='>=3.9,<3.10.0a0'] -> pip
# pyqt -> python[version='>=3.11,<3.12.0a0'] -> pip
# anyio -> python[version='>=3.11,<3.12.0a0'] -> pip
# defusedxml -> python -> pip
# sip -> python[version='>=3.11,<3.12.0a0'] -> pip
# cycler -> python[version='>=3.6'] -> pip
# pandas -> python[version='>=3.11,<3.12.0a0'] -> pip
# chardet -> python[version='>=3.11,<3.12.0a0'] -> pip
# mkl-service -> python[version='>=3.11,<3.12.0a0'] -> pip
# toml -> python[version='>=2.7'] -> pip
# pysocks -> python[version='>=3.8,<3.9.0a0'] -> pip
# typing_extensions -> python[version='>=3.8,<3.9.0a0'] -> pip
#
# Package tk conflicts for:
# r-lubridate -> r-base[version='>=4.1,<4.2.0a0'] -> tk[version='8.6.*|>=8.6.12,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# matplotlib -> python[version='>=3.9,<3.10.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.12,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# r-vctrs -> r-base[version='>=4.1,<4.2.0a0'] -> tk[version='>=8.6.12,<8.7.0a0']
# chardet -> python[version='>=3.11,<3.12.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.12,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# r-pander -> r-base[version='>=4.1,<4.2.0a0'] -> tk[version='>=8.6.12,<8.7.0a0|>=8.6.8,<8.7.0a0']
# typing-extensions -> python[version='>=3.8,<3.9.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.12,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# pip -> python[version='>=3.11,<3.12.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.12,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# jedi -> python[version='>=3.11,<3.12.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.12,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# conda-build -> python[version='>=3.10,<3.11.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.12,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# ninja -> python -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.12,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# ujson -> python[version='>=3.11,<3.12.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.12,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# r-mass -> r-base[version='>=4.1,<4.2.0a0'] -> tk[version='8.6.*|>=8.6.12,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# conda-repo-cli -> python[version='>=3.10,<3.11.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.12,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# scikit-learn -> python[version='>=3.10,<3.11.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.12,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# click -> python[version='>=3.11,<3.12.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.12,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# numexpr -> python[version='>=3.11,<3.12.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.12,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# r-cli -> r-base[version='>=4.1,<4.2.0a0'] -> tk[version='8.6.*|>=8.6.12,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# soupsieve -> python[version='>=3.8,<3.9.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.12,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# backports -> python -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.12,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# asttokens -> python[version='>=3.5'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.12,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# r-lifecycle -> r-base[version='>=4.1,<4.2.0a0'] -> tk[version='>=8.6.12,<8.7.0a0']
# r-r6 -> r-base[version='>=4.1,<4.2.0a0'] -> tk[version='8.6.*|>=8.6.12,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# jinja2 -> python[version='>=3.11,<3.12.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.12,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# scipy -> python[version='>=3.11,<3.12.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.12,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# fonttools -> python[version='>=3.6'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.12,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# backports.tempfile -> python -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.12,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# krb5 -> tk[version='8.6.*|>=8.6.7,<8.7.0a0|>=8.6.8,<8.7.0a0']
# pytz -> python[version='>=3.11,<3.12.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.12,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# nbclassic -> python[version='>=3.9,<3.10.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.12,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# navigator-updater -> python[version='>=3.10,<3.11.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.12,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# platformdirs -> python[version='>=3.11,<3.12.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.12,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# jupyterlab_pygments -> python -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.12,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# sip -> python[version='>=3.11,<3.12.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.12,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# defusedxml -> python -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.12,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# requests -> python[version='>=3.11,<3.12.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.12,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# r-pryr -> r-base[version='>=4.1,<4.2.0a0'] -> tk[version='8.6.*|>=8.6.12,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# glib -> python= -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.12,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# setuptools -> python[version='>=3.10,<3.11.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.12,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# mistune -> python[version='>=3.11,<3.12.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.12,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# curl -> krb5[version='>=1.17.1,<1.18.0a0'] -> tk[version='>=8.6.7,<8.7.0a0|>=8.6.8,<8.7.0a0']
# tktable -> tk[version='>=8.6.7,<8.7.0a0']
# cycler -> python[version='>=3.6'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.12,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# tornado -> python[version='>=3.11,<3.12.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.12,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# pyqt -> python[version='>=3.11,<3.12.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.12,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# future -> python[version='>=3.11,<3.12.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.12,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# r-rlang -> r-base[version='>=4.1,<4.2.0a0'] -> tk[version='8.6.*|>=8.6.12,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# et_xmlfile -> python[version='>=3.11,<3.12.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.12,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# nbformat -> python[version='>=3.11,<3.12.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.12,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# typing_extensions -> python[version='>=3.8,<3.9.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.12,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# r-summarytools -> r-base[version='>=4.1,<4.2.0a0'] -> tk[version='>=8.6.12,<8.7.0a0']
# qtpy -> python[version='>=3.11,<3.12.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.12,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# r-timechange -> r-base[version='>=4.1,<4.2.0a0'] -> tk[version='>=8.6.12,<8.7.0a0|>=8.6.8,<8.7.0a0']
# python-dateutil -> python -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.12,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# ...
# gfortran_osx-64 -> libgfortran-devel_osx-64[version='11.2.0|11.3.0']
# r-base -> gfortran_osx-64=11 -> libgfortran-devel_osx-64[version='11.2.0|11.3.0']
# gfortran_osx-64 -> gfortran_impl_osx-64==11.3.0 -> libgfortran-devel_osx-64[version='11.2.0.*|11.3.0.*']
#
# Package libxcb conflicts for:
# xorg-libx11 -> libxcb[version='1.*|>=1.13,<1.14.0a0']
# xorg-libxext -> xorg-libx11[version='>=1.7.2,<2.0a0'] -> libxcb[version='1.*|>=1.13,<1.14.0a0']
# xorg-libxrender -> xorg-libx11[version='>=1.7.0,<2.0a0'] -> libxcb[version='1.*|>=1.13,<1.14.0a0']
# imagemagick -> xorg-libx11 -> libxcb[version='1.*|>=1.13,<1.14.0a0']
# xorg-libxt -> xorg-libx11[version='>=1.7.0,<2.0a0'] -> libxcb[version='1.*|>=1.13,<1.14.0a0']
#
# Package colorama conflicts for:
# conda-build -> tqdm -> colorama
# conda[version='>=23.3.1'] -> tqdm[version='>=4'] -> colorama
# conda-verify -> tqdm -> colorama
# tqdm -> colorama
# conda-package-handling -> tqdm -> colorama
# anaconda-client -> tqdm[version='>=4.56.0'] -> colorama
#
# Package argon2-cffi conflicts for:
# notebook -> argon2-cffi
# notebook-shim -> jupyter_server[version='>=1.8,<3'] -> argon2-cffi
# jupyter_server -> argon2-cffi
# nbclassic -> argon2-cffi
#
# Package pathlib2 conflicts for:
# ipython -> pathlib2
# pickleshare -> pathlib2
# ipykernel -> ipython[version='>=5.0'] -> pathlib2
# pluggy -> importlib_metadata[version='>=0.12'] -> pathlib2
# nbconvert -> testpath -> pathlib2
# jsonschema -> importlib_metadata -> pathlib2
#
# Package openjpeg conflicts for:
# pillow -> openjpeg[version='>=2.3.0,<3.0a0']
# anaconda-navigator -> pillow[version='>=8.2'] -> openjpeg[version='>=2.3.0,<3.0a0']
# graphviz -> poppler -> openjpeg[version='>=2.2.0,<3.0a0|>=2.3.0,<3.0a0|>=2.4.0,<3.0a0']
# matplotlib-base -> pillow[version='>=6.2.0'] -> openjpeg[version='>=2.3.0,<3.0a0']
# r-magick -> imagemagick[version='>=7.1.0.49,<7.1.1.0a0'] -> openjpeg[version='>=2.5.0,<3.0a0']
# imagemagick -> openjpeg[version='>=2.5.0,<3.0a0']
#
# Package pkg-config conflicts for:
# imagemagick -> pkg-config
# r-magick -> imagemagick[version='>=7.1.0.49,<7.1.1.0a0'] -> pkg-config
#
# Package conda-env conflicts for:
# navigator-updater -> conda -> conda-env[version='>=2.6']
# anaconda-navigator -> conda!=22.11.* -> conda-env[version='>=2.6']
# conda-token -> conda[version='>=4.3'] -> conda-env[version='>=2.6']
# conda-build -> conda[version='>=4.5'] -> conda-env[version='>=2.6']
#
# Package xorg-libice conflicts for:
# xorg-libsm -> xorg-libice=1.0
# xorg-libxt -> xorg-libice=1.0
# imagemagick -> xorg-libxt -> xorg-libice=1.0
#
# Package pyrsistent conflicts for:
# nbformat -> jsonschema[version='>=2.6'] -> pyrsistent[version='!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0|>=0.14.0,!=0.17.0,!=0.17.1,!=0.17.2|>=0.14.0']
# jsonschema -> pyrsistent[version='!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0|>=0.14.0,!=0.17.0,!=0.17.1,!=0.17.2|>=0.14.0']
#
# Package r-memoise conflicts for:
# r-cli -> r-crayon -> r-memoise
# r-summarytools -> r-lubridate -> r-memoise
# r-crayon -> r-memoise
# r-tibble -> r-crayon -> r-memoise
# r-lobstr -> r-crayon -> r-memoise
# r-lubridate -> r-memoise
#
# Package pyqt conflicts for:
# anaconda-navigator -> navigator-updater -> pyqt[version='>=5.6']
# navigator-updater -> pyqt[version='>=5.6|>=5.6,<6.0a0']
# anaconda-navigator -> pyqt[version='>=5.6,<5.15|>=5.6,<6.0a0']
#
# Package argon2-cffi-bindings conflicts for:
# notebook -> argon2-cffi -> argon2-cffi-bindings
# argon2-cffi -> argon2-cffi-bindings
# jupyter_server -> argon2-cffi -> argon2-cffi-bindings
# nbclassic -> argon2-cffi -> argon2-cffi-bindings
#
# Package nbclient conflicts for:
# nbconvert -> nbclient[version='>=0.5.0|>=0.5.0,<0.6.0']
# jupyter_server -> nbconvert[version='>=6.4.4'] -> nbclient[version='>=0.5.0|>=0.5.0,<0.6.0']
# notebook -> nbconvert[version='>=5'] -> nbclient[version='>=0.5.0|>=0.5.0,<0.6.0']
# nbclassic -> nbconvert[version='>=5'] -> nbclient[version='>=0.5.0|>=0.5.0,<0.6.0']
#
# Package libclang13 conflicts for:
# qt-main -> libclang[version='>=14.0.6,<15.0a0'] -> libclang13[version='14.0.6|15.0.7',build='default_hc4b5f92_1|default_hc2d90ac_0|default_habbcc1a_1']
# qt-main -> libclang13[version='>=14.0.6|>=15.0.5']
# qt-webengine -> qt-main[version='>=5.15,<6.0a0'] -> libclang13[version='>=14.0.6|>=15.0.5']
# libclang -> libclang13[version='14.0.6|15.0.7',build='default_hc4b5f92_1|default_hc2d90ac_0|default_habbcc1a_1']
# pyqt -> qt-main=5.15 -> libclang13[version='>=14.0.6|>=15.0.5']
# qtwebkit -> qt-main[version='>=5.15.2,<5.16.0a0'] -> libclang13[version='>=14.0.6|>=15.0.5']
#
# Package libclang-cpp14 conflicts for:
# clang -> clang-14==14.0.6=default_hd95374b_1 -> libclang-cpp14==14.0.6[build='default_h32c6d10_0|default_hd95374b_1']
# clang-14 -> libclang-cpp14==14.0.6[build='default_h32c6d10_0|default_hd95374b_1']
#
# Package r-cachem conflicts for:
# r-lubridate -> r-memoise -> r-cachem
# r-crayon -> r-memoise -> r-cachem
#
# Package r-stringr conflicts for:
# r-reshape2 -> r-stringr
# r-lubridate -> r-stringr
# r-tidyr -> r-stringr[version='>=1.5.0']
# r-pryr -> r-stringr
# r-rapportools -> r-reshape2 -> r-stringr
# r-tidyr -> r-reshape2 -> r-stringr
# r-summarytools -> r-lubridate -> r-stringr[version='>=1.5.0']
#
# Package atk-1.0 conflicts for:
# gtk2 -> atk-1.0[version='>=1.29.2|>=2.36.0']
# graphviz -> gtk2 -> atk-1.0[version='>=1.29.2|>=2.36.0']
#
# Package r-lobstr conflicts for:
# r-pryr -> r-lobstr
# r-summarytools -> r-pryr -> r-lobstr
#
# Package pandocfilters conflicts for:
# nbconvert -> pandocfilters[version='>=1.4.1']
# nbclassic -> nbconvert[version='>=5'] -> pandocfilters[version='>=1.4.1']
# jupyter_server -> nbconvert[version='>=6.4.4'] -> pandocfilters[version='>=1.4.1']
# notebook -> nbconvert[version='>=5'] -> pandocfilters[version='>=1.4.1']
#
# Package nbconvert conflicts for:
# notebook-shim -> jupyter_server[version='>=1.8,<3'] -> nbconvert[version='>=6.4.4']
# nbclassic -> nbconvert[version='>=5']
# nbclassic -> jupyter_server[version='>=1.8'] -> nbconvert[version='<6.0|>=6.4.4']
# jupyter_server -> nbconvert[version='>=6.4.4']
# notebook -> nbconvert[version='<6.0|>=5']
#
# Package bleach conflicts for:
# nbclassic -> nbconvert[version='>=5'] -> bleach
# notebook -> nbconvert[version='>=5'] -> bleach
# nbconvert -> bleach
# jupyter_server -> nbconvert[version='>=6.4.4'] -> bleach
#
# Package clangxx conflicts for:
# r-base -> clangxx_osx-64[version='>=14'] -> clangxx[version='10.0.0.*|12.0.0.*|14.0.6.*|4.0.1.*']
# compiler-rt_osx-64 -> clangxx[version='10.0.0.*|12.0.0.*|14.0.6.*']
# compiler-rt -> clangxx[version='10.0.0.*|12.0.0.*|14.0.6.*']
# clangxx_osx-64 -> clangxx[version='10.0.0.*|12.0.0.*|14.0.6.*|4.0.1.*']
# clang_osx-64 -> compiler-rt=14.0.6 -> clangxx[version='10.0.0.*|12.0.0.*|14.0.6.*']
#
# Package prometheus_client conflicts for:
# notebook-shim -> jupyter_server[version='>=1.8,<3'] -> prometheus_client
# nbclassic -> prometheus_client
# jupyter_server -> prometheus_client
# notebook -> prometheus_client
#
# Package gdbm conflicts for:
# imagemagick -> perl= -> gdbm[version='>=1.18|>=1.18,<1.19.0a0']
# perl -> gdbm[version='>=1.18|>=1.18,<1.19.0a0']
#
# Package pandas conflicts for:
# seaborn -> statsmodels[version='>=0.5.0'] -> pandas[version='>=0.14|>=0.21|>=1.0']
# seaborn -> pandas[version='>=0.14.0|>=0.22.0|>=0.23|>=0.25']
#
# Package comm conflicts for:
# ipykernel -> comm[version='>=0.1.1']
# notebook -> ipykernel -> comm[version='>=0.1.1']
# nbclassic -> ipykernel -> comm[version='>=0.1.1']
#
# Package xorg-libx11 conflicts for:
# xorg-libxext -> xorg-libx11[version='>=1.7.2,<2.0a0']
# xorg-libxrender -> xorg-libx11[version='>=1.7.0,<2.0a0']
# imagemagick -> xorg-libx11
# xorg-libxt -> xorg-libx11[version='>=1.7.0,<2.0a0']
# imagemagick -> xorg-libxext -> xorg-libx11[version='>=1.7.0,<2.0a0|>=1.7.2,<2.0a0']
# r-magick -> imagemagick[version='>=7.1.0.49,<7.1.1.0a0'] -> xorg-libx11
#
# Package soupsieve conflicts for:
# nbconvert -> beautifulsoup4 -> soupsieve[version='>1.2|>=1.2']
# beautifulsoup4 -> soupsieve[version='>1.2|>=1.2']
# conda-build -> beautifulsoup4 -> soupsieve[version='>1.2|>=1.2']
#
# Package mysql-common conflicts for:
# mysql-libs -> mysql-common==8.0.32=h7ebae80_0
# qt-main -> mysql-libs[version='>=8.0.31,<8.1.0a0'] -> mysql-common==8.0.32=h7ebae80_0
#
# Package mpc conflicts for:
# gfortran_osx-64 -> gfortran_impl_osx-64==11.3.0 -> mpc
# gfortran_impl_osx-64 -> mpc
#
# Package r-pkgconfig conflicts for:
# r-purrr -> r-tibble -> r-pkgconfig[version='>=2.0.1|>=2.0.2']
# r-tibble -> r-pkgconfig[version='>=2.0.2']
# r-tidyr -> r-tibble[version='>=2.1.1'] -> r-pkgconfig[version='>=2.0.1|>=2.0.2']
# r-summarytools -> r-dplyr -> r-pkgconfig[version='>=2.0.1|>=2.0.2']
# r-dplyr -> r-tibble[version='>=2.0.0'] -> r-pkgconfig[version='>=2.0.2']
# r-dplyr -> r-pkgconfig[version='>=2.0.1']
#
# Package r-codetools conflicts for:
# r-summarytools -> r-pryr -> r-codetools
# r-pryr -> r-codetools
#
# Package backports.weakref conflicts for:
# tensorflow -> tensorflow-base==2.0.0=mkl_py27h66b1bf0_0 -> backports.weakref[version='>=1.0.0inf.1,<2.0a0|>=1.0rc1']
# backports.tempfile -> backports.weakref
# conda-verify -> backports.tempfile -> backports.weakref
#
# Package scikit-learn conflicts for:
# py-xgboost -> scikit-learn
# xgboost -> py-xgboost==1.7.3=py311hecd8cb5_0 -> scikit-learn
#
# Package twisted conflicts for:
# prometheus_client -> twisted
# jupyter_server -> prometheus_client -> twisted
# notebook -> prometheus_client -> twisted
# nbclassic -> prometheus_client -> twisted
#
# Package munkres conflicts for:
# matplotlib-base -> fonttools[version='>=4.22.0'] -> munkres
# fonttools -> munkres
#
# Package jbig conflicts for:
# imagemagick -> jbig
# r-magick -> imagemagick[version='>=7.1.0.49,<7.1.1.0a0'] -> jbig
#
# Package backports.tempfile conflicts for:
# conda-build -> conda-verify -> backports.tempfile
# conda-verify -> backports.tempfile
#
# Package pathlib conflicts for:
# conda-repo-cli -> pathlib
# anaconda-navigator -> conda-repo-cli -> pathlib
#
# Package bottleneck conflicts for:
# seaborn -> pandas[version='>=0.25'] -> bottleneck[version='>=1.2.1|>=1.3.1|>=1.3.2']
# pandas -> bottleneck[version='>=1.2.1|>=1.3.1|>=1.3.2']
#
# Package html5lib conflicts for:
# nbconvert -> bleach -> html5lib[version='>=0.99999999|>=0.99999999pre,!=1.0b1,!=1.0b2,!=1.0b3,!=1.0b4,!=1.0b5,!=1.0b6,!=1.0b7,!=1.0b8']
# bleach -> html5lib[version='>=0.99999999|>=0.99999999pre,!=1.0b1,!=1.0b2,!=1.0b3,!=1.0b4,!=1.0b5,!=1.0b6,!=1.0b7,!=1.0b8']
#
# Package pandoc conflicts for:
# nbconvert -> pandoc[version='>=1.12.1|>=1.12.1,<2.0.0']
# nbclassic -> nbconvert[version='>=5'] -> pandoc[version='>=1.12.1|>=1.12.1,<2.0.0']
# r-rapportools -> r-pander -> pandoc
# notebook -> nbconvert[version='>=5'] -> pandoc[version='>=1.12.1|>=1.12.1,<2.0.0']
# r-pander -> pandoc
# jupyter_server -> nbconvert -> pandoc[version='>=1.12.1|>=1.12.1,<2.0.0']
# r-summarytools -> r-pander -> pandoc
#
# Package r-timechange conflicts for:
# r-lubridate -> r-timechange[version='>=0.1.1']
# r-summarytools -> r-lubridate -> r-timechange[version='>=0.1.1']
#
# Package brotlipy conflicts for:
# urllib3 -> brotlipy[version='>=0.6.0']
# requests -> urllib3[version='>=1.21.1,<1.27'] -> brotlipy[version='>=0.6.0']
# anaconda-client -> urllib3[version='>=1.26.4'] -> brotlipy[version='>=0.6.0']
#
# Package perl conflicts for:
# imagemagick -> perl[version='*|>=5.32.1,<5.33.0a0',build=*_perl5]
# r-magick -> imagemagick[version='>=7.1.0.49,<7.1.1.0a0'] -> perl[version='*|>=5.32.1,<5.33.0a0',build=*_perl5]
#
# Package ninja-base conflicts for:
# atk-1.0 -> ninja -> ninja-base==1.10.2=haf03e11_5
# ninja -> ninja-base==1.10.2=haf03e11_5
#
# Package numpydoc conflicts for:
# ipython -> jedi[version='>=0.10,<0.18'] -> numpydoc
# jedi -> numpydoc
#
# Package olefile conflicts for:
# pillow -> olefile
# matplotlib-base -> pillow[version='>=6.2.0'] -> olefile
# anaconda-navigator -> pillow[version='>=8.2'] -> olefile
#
# Package xorg-libxt conflicts for:
# imagemagick -> xorg-libxt
# r-magick -> imagemagick[version='>=7.1.0.49,<7.1.1.0a0'] -> xorg-libxt
#
# Package executing conflicts for:
# stack_data -> executing
# ipython -> stack_data -> executing
#
# Package xorg-libsm conflicts for:
# imagemagick -> xorg-libxt -> xorg-libsm=1.2
# xorg-libxt -> xorg-libsm=1.2
#
# Package anaconda-client conflicts for:
# conda-repo-cli -> anaconda-client[version='>=1.7.2']
# anaconda-navigator -> conda-repo-cli -> anaconda-client[version='>=1.7.2']
# anaconda-navigator -> anaconda-client[version='>=1.6|>=1.6.12|>=1.6.14']
#
# Package gtk2 conflicts for:
# imagemagick -> graphviz[version='>=6.0.2,<7.0a0'] -> gtk2
# graphviz -> gtk2
#
# Package pickleshare conflicts for:
# ipython -> pickleshare
# ipykernel -> ipython[version='>=7.23.1'] -> pickleshare
#
# Package libpq conflicts for:
# pyqt -> qt-main=5.15 -> libpq[version='>=12.9,<13.0a0|>=14.5,<15.0a0']
# qtwebkit -> qt-main[version='>=5.15.2,<5.16.0a0'] -> libpq[version='>=12.9,<13.0a0|>=14.5,<15.0a0']
# qt-main -> libpq[version='>=12.9,<13.0a0|>=14.5,<15.0a0']
# qt-webengine -> qt-main[version='>=5.15,<6.0a0'] -> libpq[version='>=12.9,<13.0a0|>=14.5,<15.0a0']
#
# Package future conflicts for:
# conda-verify -> future
# tensorflow -> tensorflow-base==2.0.0=mkl_py27h66b1bf0_0 -> future
# conda-build -> conda-verify -> future
#
# Package qtpy conflicts for:
# anaconda-navigator -> qtpy[version='>=1.2|>=1.4.1']
# navigator-updater -> qtpy[version='>=1.2|>=1.4.1']
#
# Package prompt_toolkit conflicts for:
# ipython -> prompt_toolkit[version='>=1.0.4,<2.0.0|>=2.0.0,<3|>=2.0.0,<4,!=3.0.0,!=3.0.1']
# ipykernel -> ipython[version='>=5.0'] -> prompt_toolkit[version='>=1.0.4,<2.0.0|>=2.0.0,<3|>=2.0.0,<4,!=3.0.0,!=3.0.1']
#
# Package jsonpointer conflicts for:
# conda[version='>=23.3.1'] -> jsonpatch[version='>=1.32'] -> jsonpointer[version='>=1.9']
# jsonpatch -> jsonpointer[version='>=1.9']
#
# Package lzo conflicts for:
# python-libarchive-c -> libarchive -> lzo[version='>=2.10,<3.0a0']
# conda-build -> libarchive -> lzo[version='>=2.10,<3.0a0']
# conda-package-handling -> libarchive[version='>=3.3.3'] -> lzo[version='>=2.10,<3.0a0']
# libarchive -> lzo[version='>=2.10,<3.0a0']
#
# Package matplotlib-base conflicts for:
# seaborn -> matplotlib-base[version='>=3.1,!=3.6.1']
# matplotlib -> matplotlib-base[version='3.1.2|3.1.2|3.1.2|3.1.3|3.1.3|3.1.3|>=3.2.1,<3.2.2.0a0|>=3.2.2,<3.2.3.0a0|>=3.3.1,<3.3.2.0a0|>=3.3.2,<3.3.3.0a0|>=3.3.4,<3.3.5.0a0|>=3.4.2,<3.4.3.0a0|>=3.4.3,<3.4.4.0a0|>=3.5.0,<3.5.1.0a0|>=3.5.1,<3.5.2.0a0|>=3.5.2,<3.5.3.0a0|>=3.5.3,<3.5.4.0a0|>=3.6.2,<3.6.3.0a0|>=3.7.0,<3.7.1.0a0|>=3.7.1,<3.7.2.0a0',build='py36h9aa3819_1|py36h9aa3819_0|py37h9aa3819_0|py38h9aa3819_0|py38h9aa3819_1|py37h9aa3819_1']
# seaborn -> matplotlib[version='>=2.2'] -> matplotlib-base[version='3.1.2|3.1.2|3.1.2|3.1.3|3.1.3|3.1.3|>=3.2.1,<3.2.2.0a0|>=3.2.2,<3.2.3.0a0|>=3.3.1,<3.3.2.0a0|>=3.3.2,<3.3.3.0a0|>=3.3.4,<3.3.5.0a0|>=3.4.2,<3.4.3.0a0|>=3.4.3,<3.4.4.0a0|>=3.5.0,<3.5.1.0a0|>=3.5.1,<3.5.2.0a0|>=3.5.2,<3.5.3.0a0|>=3.5.3,<3.5.4.0a0|>=3.6.2,<3.6.3.0a0|>=3.7.0,<3.7.1.0a0|>=3.7.1,<3.7.2.0a0',build='py36h9aa3819_1|py36h9aa3819_0|py37h9aa3819_0|py38h9aa3819_0|py38h9aa3819_1|py37h9aa3819_1']
#
# Package libvorbis conflicts for:
# gst-plugins-base -> libvorbis[version='>=1.3.7,<1.4.0a0']
# qt-main -> gst-plugins-base[version='>=1.21.2,<1.22.0a0'] -> libvorbis[version='>=1.3.7,<1.4.0a0']
#
# Package brotli-bin conflicts for:
# brotli -> brotli-bin==1.0.9=hca72f7f_7
# fonttools -> brotli[version='>=1.0.1'] -> brotli-bin==1.0.9=hca72f7f_7
#
# Package notebook-shim conflicts for:
# nbclassic -> notebook-shim[version='>=0.1.0']
# notebook -> nbclassic[version='>=0.4.7'] -> notebook-shim[version='>=0.1.0']
#
# Package parso conflicts for:
# ipython -> jedi[version='>=0.16'] -> parso[version='0.1.0|>=0.1.0,<0.2|>=0.2.0|>=0.3.0|>=0.5.0|>=0.5.2|>=0.7.0|>=0.7.0,<0.8.0|>=0.8.0,<0.9.0']
# jedi -> parso[version='0.1.0|>=0.1.0,<0.2|>=0.2.0|>=0.3.0|>=0.5.0|>=0.5.2|>=0.7.0|>=0.7.0,<0.8.0|>=0.8.0,<0.9.0']The following specifications were found to be incompatible with your system:
#
#   - feature:/osx-64::__osx==10.16=0
#   - feature:|@/osx-64::__osx==10.16=0
#   - matplotlib -> matplotlib-base[version='>=3.7.1,<3.7.2.0a0'] -> __osx[version='>=10.11']
#   - matplotlib-base -> __osx[version='>=10.11']
#   - pyqt -> qtwebkit=5 -> __osx[version='>=10.12']
#   - qtwebkit -> __osx[version='>=10.12']
#   - seaborn -> matplotlib-base[version='>=3.1,!=3.6.1'] -> __osx[version='>=10.11']
#
# Your installed version is: 10.16
#
#
#
# Note: you may need to restart the kernel to use updated packages.
